# %%
import findspark
findspark.init()

# %%
#importing libraries
from __future__ import division
import operator
from pyspark import SparkContext
from pyspark.sql import SQLContext
from pyspark.sql.functions import col
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt

sc = SparkContext("local", "Decision Tree")
sqlContext = SQLContext(sc)
attr_name_info_gain = {}
G = nx.DiGraph()
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#read file
df = pd.read_csv('census.csv')
#drop the null rows
df = df.dropna()
df['y'] = np.where(df['income']=='-50000','no','yes')

# %%
df = df.drop(['A1', 'income', 'C3', 'D4', 'F6', 'I9', 'Q17', 'R18','S19', 'W23', 'V22', 'F32', 'G33', 'H34', 'M39', 'Y25', 'D30', 'Z26', 'A27', 'C29'], axis=1)
df = df.dropna()
df.columns
# Out:
# Index(['B2', 'E5', 'G7', 'H8', 'J10', 'K11', 'L12', 'M13', 'N14', 'O15', 'P16',
#        'T20', 'U21', 'X24', 'B28', 'E31', 'I35', 'J36', 'K37', 'L38', 'N40',
#        'y'],
#       dtype='object')

# %%
df.head()
# Out:
#                                B2                          E5  \
# 0                 Not in universe        High school graduate
# 1  Self-employed-not incorporated  Some college but no degree
# 2                 Not in universe                  10th grade
# 3                 Not in universe                    Children
# 4                 Not in universe                    Children
#
#                 G7             H8                                  J10  \
# 0  Not in universe        Widowed                      Not in universe
# 1  Not in universe       Divorced  Precision production craft & repair
# 2      High school  Never married                      Not in universe
# 3  Not in universe  Never married                      Not in universe
# 4  Not in universe  Never married                      Not in universe
#
#                          K11        L12     M13              N14  \
# 0                      White  All other  Female  Not in universe
# 1                      White  All other    Male  Not in universe
# 2  Asian or Pacific Islander  All other  Female  Not in universe
# 3                      White  All other  Female  Not in universe
# 4                      White  All other  Female  Not in universe
#
#                O15  ...              U21                            X24  \
# 0  Not in universe  ...  Not in universe  Other relative of householder
# 1  Not in universe  ...            South                    Householder
# 2  Not in universe  ...  Not in universe              Child 18 or older
# 3  Not in universe  ...  Not in universe   Child under 18 never married
# 4  Not in universe  ...  Not in universe   Child under 18 never married
#
#                                 B28                   E31  \
# 0  Not in universe under 1 year old       Not in universe
# 1                                No       Not in universe
# 2  Not in universe under 1 year old       Not in universe
# 3                               Yes  Both parents present
# 4                               Yes  Both parents present
#
#                                    I35 J36              K37  L38 N40   y
# 0    Native- Born in the United States   0  Not in universe    2  95  no
# 1    Native- Born in the United States   0  Not in universe    2  94  no
# 2  Foreign born- Not a citizen of U S    0  Not in universe    2  95  no
# 3    Native- Born in the United States   0  Not in universe    0  94  no
# 4    Native- Born in the United States   0  Not in universe    0  94  no
#
# [5 rows x 22 columns]

# %%
attrs = ['B2', 'E5', 'G7', 'H8', 'J10', 'K11', 'L12', 'M13', 'N14', 'O15', 'P16','T20', 'U21', 'X24', 'B28', 'E31', 'I35', 'J36', 'K37', 'L38','N40']
attrs_type = { "B2":"string", 'E5':"string", 'G7':"string", 'H8':"string", 'J10':"string", 'K11':"string", 'L12':"string", 'M13':"string", 'N14':"string", 'O15':"string", 'P16':"string",'T20':"string", 'U21':"string", 'X24':"string", 'B28':"string", 'E31':"string", 'I35':"string", 'J36':"integer", 'K37':"string", 'L38':"integer",'N40':"integer"}

# %%
def calculate_info_gain(entropy, joined_df, total_elements):
    attr_entropy = 0.0
    split_info=0.0
    for anAttributeData in joined_df.rdd.collect():
        yes_class_count = anAttributeData[1]
        no_class_count = anAttributeData[2]
        if yes_class_count is None:
            yes_class_count = 0
        elif no_class_count is None:
            no_class_count = 0

        count_of_class = yes_class_count + no_class_count
        y = (-(count_of_class)/total_elements)*np.log2((count_of_class)/total_elements)
        split_info = split_info + y
        # do the summation part e.g. if age is 56, 60, 45 then its sum of entropy for each of these element
        classmap = {'y' : yes_class_count, 'n' : no_class_count}
        attr_entropy = attr_entropy + ((count_of_class / total_elements) *\
                                       calculate_entropy(count_of_class, classmap))

    gain = entropy - attr_entropy
    
    gain_ratio = gain/split_info
    return gain_ratio

# %%
def get_attr_info_gain_data_prep(attr_name, data, entropy, total_elements, where_condition):

    if not where_condition:
        attr_grp_y = data.where(col('y') == 'yes').groupBy(attr_name).agg({"y": 'count'})\
            .withColumnRenamed('count(y)','played_count')
    else:
        attr_grp_y = data.where(" y like '%yes%'  " + where_condition).groupBy(attr_name).agg({"y": 'count'})\
            .withColumnRenamed('count(y)','played_count')

    if not where_condition:
        attr_grp_n = data.where(col('y') == 'no').groupBy(attr_name).agg({"y": 'count'})\
            .withColumnRenamed(attr_name,'n_' + attr_name)\
            .withColumnRenamed('count(y)','not_played_count')
    else:
        attr_grp_n = data.where(" y like '%no%'  " + where_condition).groupBy(attr_name).agg({"y": 'count'})\
            .withColumnRenamed(attr_name,'n_' + attr_name)\
            .withColumnRenamed('count(y)','not_played_count')

    joined_df = attr_grp_y.join(attr_grp_n, on = [col(attr_grp_y.columns[0]) == col(attr_grp_n.columns[0])], how='outer' )\
        .withColumn("total", col(attr_grp_y.columns[1]) + col(attr_grp_n.columns[1]))\
        .select(attr_grp_y.columns[0], attr_grp_y.columns[1],\
                 attr_grp_n.columns[1]) \

    gain_for_attribute = calculate_info_gain(entropy, joined_df, total_elements)
    attr_name_info_gain[attr_name] = gain_for_attribute
    
    
    
    
   #joined_df = attr_grp_y.join(attr_grp_n, on = [col(attr_grp_y.columns[0]) == col(attr_grp_n.columns[0])], how='outer' )\
   #    .withColumn("total", col(attr_grp_y.columns[0]) + col(attr_grp_n.columns[0]))\
   #    .select(attr_grp_y.columns[0], attr_grp_y.columns[1],\
   #             attr_grp_n.columns[1]) \

   #gain_for_attribute = calculate_info_gain(entropy, joined_df, total_elements)
   #attr_name_info_gain[attr_name] = gain_for_attribute

# %%
def calculate_entropy(total_elements, elements_in_each_class):
    # for target set S having 2 class 0 and 1, the entropy is -p0logp0 -p1logp1
    # here the log is of base 2
    # elements_in_each_class is a dictionary where the key is class label and the
    # value is number of elements in that class
    keysInMap = list(elements_in_each_class.keys())
    entropy = 0.0

    for aKey in keysInMap:
        number_of_elements_in_class = elements_in_each_class.get(aKey)
        if number_of_elements_in_class == 0:
            continue
        ratio = number_of_elements_in_class/total_elements
        entropy = entropy - ratio * np.log2(ratio)

    return entropy

# %%
def process_dataset(excludedAttrs, data, played, notplayed, where_condition):
    total_elements = played + notplayed
    subs_info = {"played" : played, "notplayed" : notplayed}
    entropy = calculate_entropy(total_elements, subs_info)
    print ("entropy is " + str(entropy))
    global attr_name_info_gain
    attr_name_info_gain = dict()

    for attr in attrs:
        if attr not in excludedAttrs:
            get_attr_info_gain_data_prep(attr, data, entropy, total_elements, where_condition)

# %%
def build_tree(max_gain_attr, processed_attrs, data, where_condition):
    attrValues = sqlContext.sql("select distinct " + max_gain_attr + " from data  where 1==1 " + where_condition)
    orig_where_condition = where_condition

    for aValueForMaxGainAttr in attrValues.rdd.collect():
        adistinct_value_for_attr = aValueForMaxGainAttr[0]
        G.add_edges_from([(max_gain_attr, adistinct_value_for_attr)])

        if attrs_type[max_gain_attr] == "string":
            where_condition = str(orig_where_condition + " and " + max_gain_attr + "=='" + adistinct_value_for_attr + "'")
        else:
            where_condition = str(orig_where_condition + " and " + max_gain_attr + "==" + str(adistinct_value_for_attr))

        played_for_attr = sqlContext.sql("select * from data where y like '%yes%' " + where_condition).count()
        notplayed_for_attr = sqlContext.sql("select * from data where y like '%no%' " + where_condition).count()
        # if either has zero value then entropy for this attr will be zero and its the last attr in the tree
        leaf_values = []
        if played_for_attr == 0 or notplayed_for_attr == 0:
            leaf_node = sqlContext.sql("select distinct y from data where 1==1 " + where_condition)
            for leaf_node_data in leaf_node.rdd.collect():
                G.add_edges_from([(adistinct_value_for_attr, str(leaf_node_data[0]))])
            continue

        process_dataset(processed_attrs, data, played_for_attr, notplayed_for_attr, where_condition)
        if not attr_name_info_gain: # we processed all attributes
            # attach leaf node
            leaf_node = sqlContext.sql("select distinct y from data where 1==1 " + where_condition)
            for leaf_node_data in leaf_node.rdd.collect():
                G.add_edges_from([(adistinct_value_for_attr, str(leaf_node_data[0]))])
            continue # we are done for this branch of tree

        # get the attr with max info gain under aValueForMaxGainAttr
        # sort by info gain
        sorted_by_info_gain = sorted(attr_name_info_gain.items(), key=operator.itemgetter(1), reverse=True)
        new_max_gain_attr = sorted_by_info_gain[0][0]
        if sorted_by_info_gain[0][1] == 0:
            # under this where condition, records dont have entropy
            leaf_node = sqlContext.sql("select distinct y from data where 1==1 " + where_condition)
            # there might be more than one leaf node
            for leaf_node_data in leaf_node.rdd.collect():
                G.add_edges_from([(adistinct_value_for_attr, str(leaf_node_data[0]))])
            continue # we are done for this branch of tree

        G.add_edges_from([(adistinct_value_for_attr, new_max_gain_attr)])
        processed_attrs.append(new_max_gain_attr)
        build_tree(new_max_gain_attr, processed_attrs, data, where_condition)

# %%
df = df.iloc[:,:]
df
# Out:
#                                     B2  \
# 0                      Not in universe
# 1       Self-employed-not incorporated
# 2                      Not in universe
# 3                      Not in universe
# 4                      Not in universe
# 5                              Private
# 6                              Private
# 7                              Private
# 8                     Local government
# 9                              Private
# 10                     Not in universe
# 11                     Not in universe
# 12                             Private
# 13                             Private
# 14                             Private
# 15                     Not in universe
# 16                             Private
# 17                     Not in universe
# 18                     Not in universe
# 19                             Private
# 20                     Not in universe
# 21      Self-employed-not incorporated
# 22                             Private
# 23                             Private
# 24                     Not in universe
# 25                     Not in universe
# 26                     Not in universe
# 27                             Private
# 28                     Not in universe
# 29                             Private
# ...                                ...
# 199493                 Not in universe
# 199494                 Not in universe
# 199495  Self-employed-not incorporated
# 199496                 Not in universe
# 199497  Self-employed-not incorporated
# 199498                         Private
# 199499                         Private
# 199500                State government
# 199501                 Not in universe
# 199502              Federal government
# 199503                         Private
# 199504                         Private
# 199505                         Private
# 199506                 Not in universe
# 199507      Self-employed-incorporated
# 199508                         Private
# 199509                Local government
# 199510                         Private
# 199511                         Private
# 199512                 Not in universe
# 199513                         Private
# 199514                         Private
# 199515                 Not in universe
# 199516                 Not in universe
# 199517                         Private
# 199518                 Not in universe
# 199519      Self-employed-incorporated
# 199520                 Not in universe
# 199521                 Not in universe
# 199522                         Private
#
#                                             E5               G7  \
# 0                         High school graduate  Not in universe
# 1                   Some college but no degree  Not in universe
# 2                                   10th grade      High school
# 3                                     Children  Not in universe
# 4                                     Children  Not in universe
# 5                   Some college but no degree  Not in universe
# 6                   Bachelors degree(BA AB BS)  Not in universe
# 7                         High school graduate  Not in universe
# 8                   Some college but no degree  Not in universe
# 9                   Some college but no degree  Not in universe
# 10                                    Children  Not in universe
# 11                        High school graduate  Not in universe
# 12                  Some college but no degree  Not in universe
# 13                        High school graduate  Not in universe
# 14                  Bachelors degree(BA AB BS)  Not in universe
# 15                                    Children  Not in universe
# 16                  Bachelors degree(BA AB BS)  Not in universe
# 17                                  10th grade  Not in universe
# 18                                  10th grade      High school
# 19                        High school graduate  Not in universe
# 20                                    Children  Not in universe
# 21                  Some college but no degree  Not in universe
# 22                  Some college but no degree  Not in universe
# 23      Masters degree(MA MS MEng MEd MSW MBA)  Not in universe
# 24                  Some college but no degree  Not in universe
# 25                                    Children  Not in universe
# 26                                    Children  Not in universe
# 27                  Some college but no degree  Not in universe
# 28                                    Children  Not in universe
# 29                  Bachelors degree(BA AB BS)  Not in universe
# ...                                        ...              ...
# 199493                                Children  Not in universe
# 199494                                Children  Not in universe
# 199495              Some college but no degree  Not in universe
# 199496                                Children  Not in universe
# 199497              Bachelors degree(BA AB BS)  Not in universe
# 199498                    High school graduate  Not in universe
# 199499              Bachelors degree(BA AB BS)  Not in universe
# 199500                       7th and 8th grade  Not in universe
# 199501                                Children  Not in universe
# 199502              Some college but no degree  Not in universe
# 199503                              11th grade  Not in universe
# 199504                    High school graduate  Not in universe
# 199505                    High school graduate  Not in universe
# 199506                                Children  Not in universe
# 199507              Some college but no degree  Not in universe
# 199508              Some college but no degree  Not in universe
# 199509               Doctorate degree(PhD EdD)  Not in universe
# 199510              Some college but no degree  Not in universe
# 199511              Some college but no degree  Not in universe
# 199512                    High school graduate  Not in universe
# 199513                               9th grade  Not in universe
# 199514                              10th grade  Not in universe
# 199515                    High school graduate  Not in universe
# 199516                                Children  Not in universe
# 199517              Bachelors degree(BA AB BS)  Not in universe
# 199518                       7th and 8th grade  Not in universe
# 199519                              11th grade  Not in universe
# 199520              Some college but no degree  Not in universe
# 199521                              10th grade      High school
# 199522                    High school graduate  Not in universe
#
#                                      H8  \
# 0                               Widowed
# 1                              Divorced
# 2                         Never married
# 3                         Never married
# 4                         Never married
# 5       Married-civilian spouse present
# 6       Married-civilian spouse present
# 7                         Never married
# 8       Married-civilian spouse present
# 9       Married-civilian spouse present
# 10                        Never married
# 11                        Never married
# 12      Married-civilian spouse present
# 13                             Divorced
# 14                        Never married
# 15                        Never married
# 16                        Never married
# 17      Married-civilian spouse present
# 18                        Never married
# 19      Married-civilian spouse present
# 20                        Never married
# 21      Married-civilian spouse present
# 22      Married-civilian spouse present
# 23      Married-civilian spouse present
# 24      Married-civilian spouse present
# 25                        Never married
# 26                        Never married
# 27      Married-civilian spouse present
# 28                        Never married
# 29                        Never married
# ...                                 ...
# 199493                    Never married
# 199494                    Never married
# 199495  Married-civilian spouse present
# 199496                    Never married
# 199497  Married-civilian spouse present
# 199498  Married-civilian spouse present
# 199499  Married-civilian spouse present
# 199500                          Widowed
# 199501                    Never married
# 199502  Married-civilian spouse present
# 199503                    Never married
# 199504  Married-civilian spouse present
# 199505  Married-civilian spouse present
# 199506                    Never married
# 199507                    Never married
# 199508            Married-spouse absent
# 199509  Married-civilian spouse present
# 199510                    Never married
# 199511  Married-civilian spouse present
# 199512  Married-civilian spouse present
# 199513                         Divorced
# 199514                          Widowed
# 199515                          Widowed
# 199516                    Never married
# 199517                    Never married
# 199518  Married-civilian spouse present
# 199519  Married-civilian spouse present
# 199520  Married-civilian spouse present
# 199521                    Never married
# 199522                    Never married
#
#                                           J10                          K11  \
# 0                             Not in universe                        White
# 1         Precision production craft & repair                        White
# 2                             Not in universe    Asian or Pacific Islander
# 3                             Not in universe                        White
# 4                             Not in universe                        White
# 5                      Professional specialty  Amer Indian Aleut or Eskimo
# 6              Executive admin and managerial                        White
# 7                Handlers equip cleaners etc                         White
# 8              Adm support including clerical                        White
# 9       Machine operators assmblrs & inspctrs                        White
# 10                            Not in universe                        White
# 11                            Not in universe                        Black
# 12        Precision production craft & repair                        White
# 13                              Other service                        White
# 14                     Professional specialty                        White
# 15                            Not in universe                        Black
# 16      Machine operators assmblrs & inspctrs                        White
# 17                            Not in universe                        White
# 18                            Not in universe                        White
# 19               Handlers equip cleaners etc                         White
# 20                            Not in universe                        Other
# 21        Precision production craft & repair                        White
# 22             Adm support including clerical                        White
# 23                     Professional specialty                        White
# 24                            Not in universe    Asian or Pacific Islander
# 25                            Not in universe                        White
# 26                            Not in universe                        Other
# 27        Precision production craft & repair                        White
# 28                            Not in universe                        White
# 29             Executive admin and managerial                        White
# ...                                       ...                          ...
# 199493                        Not in universe                        White
# 199494                        Not in universe                        White
# 199495         Executive admin and managerial                        White
# 199496                        Not in universe                        White
# 199497                                  Sales                        White
# 199498         Adm support including clerical                        White
# 199499         Executive admin and managerial                        White
# 199500           Handlers equip cleaners etc                         White
# 199501                        Not in universe                        White
# 199502         Executive admin and managerial                        White
# 199503                          Other service                        White
# 199504  Machine operators assmblrs & inspctrs                        White
# 199505         Executive admin and managerial                        White
# 199506                        Not in universe                        White
# 199507                                  Sales                        Other
# 199508         Executive admin and managerial                        White
# 199509                 Professional specialty                        White
# 199510           Handlers equip cleaners etc   Amer Indian Aleut or Eskimo
# 199511  Machine operators assmblrs & inspctrs                        White
# 199512                        Not in universe                        White
# 199513  Machine operators assmblrs & inspctrs                        White
# 199514                                  Sales                        White
# 199515                        Not in universe                        White
# 199516                        Not in universe                        Black
# 199517         Adm support including clerical                        Other
# 199518                        Not in universe                        White
# 199519         Executive admin and managerial                        White
# 199520                        Not in universe                        White
# 199521                        Not in universe                        White
# 199522                          Other service                        Black
#
#                               L12     M13              N14  \
# 0                       All other  Female  Not in universe
# 1                       All other    Male  Not in universe
# 2                       All other  Female  Not in universe
# 3                       All other  Female  Not in universe
# 4                       All other  Female  Not in universe
# 5                       All other  Female               No
# 6                       All other    Male  Not in universe
# 7                       All other  Female  Not in universe
# 8                       All other  Female               No
# 9                       All other    Male  Not in universe
# 10                      All other  Female  Not in universe
# 11                      All other  Female  Not in universe
# 12                    Do not know    Male  Not in universe
# 13      Central or South American  Female  Not in universe
# 14                      All other  Female  Not in universe
# 15                      All other  Female  Not in universe
# 16                      All other  Female  Not in universe
# 17             Mexican (Mexicano)  Female  Not in universe
# 18               Mexican-American  Female  Not in universe
# 19                      All other    Male  Not in universe
# 20               Mexican-American    Male  Not in universe
# 21                      All other    Male  Not in universe
# 22                      All other  Female               No
# 23                      All other    Male  Not in universe
# 24                      All other  Female  Not in universe
# 25                      All other    Male  Not in universe
# 26      Central or South American  Female  Not in universe
# 27                      All other    Male  Not in universe
# 28                      All other  Female  Not in universe
# 29                      All other    Male  Not in universe
# ...                           ...     ...              ...
# 199493                  All other  Female  Not in universe
# 199494                  All other    Male  Not in universe
# 199495                  All other    Male  Not in universe
# 199496                  All other    Male  Not in universe
# 199497                  All other  Female  Not in universe
# 199498                  All other  Female  Not in universe
# 199499                  All other  Female  Not in universe
# 199500                  All other  Female  Not in universe
# 199501                  All other  Female  Not in universe
# 199502              Other Spanish    Male  Not in universe
# 199503                  All other  Female  Not in universe
# 199504         Mexican (Mexicano)  Female  Not in universe
# 199505              Other Spanish  Female  Not in universe
# 199506                  All other  Female  Not in universe
# 199507  Central or South American  Female  Not in universe
# 199508                  All other    Male  Not in universe
# 199509                  All other  Female               No
# 22      Not in universe    2  95   no
# 23      Not in universe    2  94   no
# 24      Not in universe    2  94   no
# 25      Not in universe    0  94   no
# 26      Not in universe    0  94   no
# 27      Not in universe    2  95   no
# 28      Not in universe    0  95   no
# 29      Not in universe    2  94   no
# ...                 ...  ...  ..  ...
# 199493  Not in universe    0  94   no
# 199494  Not in universe    0  94   no
# 199495  Not in universe    2  94   no
# 199496  Not in universe    0  94   no
# 199497  Not in universe    2  95   no
# 199498  Not in universe    2  94   no
# 199499  Not in universe    2  95  yes
# 199500  Not in universe    2  94   no
# 199501  Not in universe    0  94   no
# 199502  Not in universe    2  95   no
# 199503  Not in universe    2  95   no
# 199504  Not in universe    2  95   no
# 199505  Not in universe    2  95   no
# 199506  Not in universe    0  94   no
# 199507  Not in universe    2  94   no
# 199508              Yes    1  95  yes
# 199509  Not in universe    2  94  yes
# 199510  Not in universe    2  94   no
# 199511  Not in universe    2  95   no
# 199512  Not in universe    2  95   no
# 199513  Not in universe    2  95   no
# 199514  Not in universe    2  94   no
# 199515  Not in universe    2  95   no
# 199516  Not in universe    0  94   no
# 199517  Not in universe    2  95   no
# 199518  Not in universe    2  95   no
# 199519  Not in universe    2  94   no
# 199520  Not in universe    2  95   no
# 199521  Not in universe    2  95   no
# 199522  Not in universe    2  94   no
#
# [198649 rows x 22 columns]

# %%
def main():
    #data = sqlContext.read.format('com.databricks.spark.csv').option('header', 'true').option('delimiter', ';').load("C:/Users/bittu/Downloads/census.csv")
    data = sqlContext.createDataFrame(df)
    data.registerTempTable('data')
    played = sqlContext.sql("select * from data WHERE y like  '%y%' ").count()
    notplayed = sqlContext.sql("select * from data WHERE y like  '%n%' ").count()
    process_dataset([], data, played, notplayed, '')
    # sort by info gain
    sorted_by_info_gain = sorted(attr_name_info_gain.items(), key=operator.itemgetter(1), reverse=True)
    processed_attrs = []
    max_gain_attr = sorted_by_info_gain[0][0]
    processed_attrs.append(max_gain_attr)
    build_tree(max_gain_attr, processed_attrs, data, '')
    nx.draw(G, with_labels=True)
    plt.show()

start_time = time.time()
main()
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# entropy is 0.33550638173549774
# entropy is 0.5182934784694512
# entropy is 0.9994730201859836
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:22: RuntimeWarning: invalid value encountered in double_scalars
# entropy is 0.9994730201859836
# entropy is 0.9994110647387552
# entropy is 0.9940302114769565
# entropy is 0.7219280948873623
# entropy is 1.0
# entropy is 1.0
# entropy is 1.0
# entropy is 1.0
# entropy is 1.0
# entropy is 1.0
# entropy is 0.8739810481273578
# entropy is 0.8112781244591328
# entropy is 0.8366407419411672
# entropy is 0.6500224216483541
# entropy is 0.6500224216483541
# entropy is 0.6500224216483541
# entropy is 0.6500224216483541
# entropy is 0.6500224216483541
# entropy is 0.6500224216483541
# entropy is 0.9182958340544896
# entropy is 1.0
# entropy is 0.21477719594366104
# entropy is 0.782444129406689
# entropy is 0.7756284362643351
# entropy is 0.9587118829771318
# entropy is 0.6900703653284017
# entropy is 0.7012065844539666
# entropy is 0.4054846695305433
